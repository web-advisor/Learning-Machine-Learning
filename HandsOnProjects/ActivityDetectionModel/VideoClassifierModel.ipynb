# %% [markdown]
# # Video Classifier using CNN and RNN :

# %%
from tensorflow_docs.vis import embed
from tensorflow import keras
from imutils import paths

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %% [markdown]
# ### Data Collection :

# %%
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

# %%
print(f"Total videos for training : {len(train_df)}")
print(f"Total videos for testing  : {len(test_df)}")

print("Training Dataframe : ")
print(train_df.sample(10))

print("Testing Dataset    : ")
print(test_df.sample(10))
# Out:
# Total videos for training : 152
# Total videos for testing  : 38
# Training Dataframe :
#      Unnamed: 0          label                                    video_name
# 144         132  roadaccidents  data/roadaccidents/RoadAccidents033_x264.mp4
# 90           60          arson                  data/arson/Arson012_x264.mp4
# 62           21         arrest                data/arrest/Arrest022_x264.mp4
# 33          152  roadaccidents  data/roadaccidents/RoadAccidents054_x264.mp4
# 109         148  roadaccidents  data/roadaccidents/RoadAccidents050_x264.mp4
# 115          37         arrest                data/arrest/Arrest038_x264.mp4
# 145         117  roadaccidents  data/roadaccidents/RoadAccidents018_x264.mp4
# 56           62          arson                  data/arson/Arson014_x264.mp4
# 130         172  roadaccidents  data/roadaccidents/RoadAccidents074_x264.mp4
# 111          23         arrest                data/arrest/Arrest024_x264.mp4
# Testing Dataset    :
#     Unnamed: 0          label                                    video_name
# 30          92          arson                  data/arson/Arson046_x264.mp4
# 1          101  roadaccidents  data/roadaccidents/RoadAccidents002_x264.mp4
# 14          89          arson                  data/arson/Arson042_x264.mp4
# 7          137  roadaccidents  data/roadaccidents/RoadAccidents038_x264.mp4
# 18           2         arrest                data/arrest/Arrest003_x264.mp4
# 11         106  roadaccidents  data/roadaccidents/RoadAccidents007_x264.mp4
# 29         138  roadaccidents  data/roadaccidents/RoadAccidents039_x264.mp4
# 8          176  roadaccidents  data/roadaccidents/RoadAccidents078_x264.mp4
# 26         116  roadaccidents  data/roadaccidents/RoadAccidents017_x264.mp4
# 9            3         arrest                data/arrest/Arrest004_x264.mp4

# %% [markdown]
# ### Feed the videos to a Network :

# %%
IMG_SIZE = 256

def crop_center_square(frame):
    y , x= frame.shape[0:2]
    min_dim = min(y,x)
    start_x = (x // 2) -  (min_dim // 2) 
    start_y = (y // 2) -  (min_dim // 2) 
    return frame[start_y : start_y+min_dim, start_x : start_x + min_dim]

def load_video(path, max_frames = 0, resize = (IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2,1,0]]
            frames.append(frame)

            if(len(frames) == max_frames):
                break
    finally:
        cap.release()
    return np.array(frames)

# %% [markdown]
# ### Transfer Learning & Feature Extraction :

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()

# %% [markdown]
# ### Label Encoding
# StringLookup layer encode the class labels as integers.

# %%
label_processor = keras.layers.StringLookup(num_oov_indices=0, vocabulary=np.unique(train_df["label"]))
print(label_processor.get_vocabulary())

labels = train_df["label"].values
labels = label_processor(labels[..., None]).numpy()
labels
# Out:
# ['arrest', 'arson', 'roadaccidents']
# array([[1],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [1],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [1],
#        [0],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [1],
#        [0],
#        [2],
#        [2],
#        [1],
#        [0],
#        [2],
#        [0],
#        [1],
#        [2],
#        [1],
#        [0],
#        [2],
#        [1],
#        [1],
#        [1],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [0],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [1],
#        [1],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [1],
#        [0],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [1],
#        [0],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [0],
#        [2],
#        [1],
#        [0],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [0],
#        [0],
#        [1],
#        [0],
#        [1],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [0],
#        [1],
#        [2],
#        [1],
#        [2],
#        [1],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0]], dtype=int64)

# %% [markdown]
# <b>Finally, we can put all the pieces together to create our data processing utility.</b>

# %%
#Define hyperparameters

IMG_SIZE = 256
BATCH_SIZE = 64
EPOCHS = 100

MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048

# %%
def prepare_all_videos(df):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()    
    
    ##take all classlabels from train_df column named 'label' and store in labels
    labels = df["label"].values

    #convert classlabels to label encoding
    labels = label_processor(labels[..., None]).numpy()

    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool") 
    frame_features = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32") 

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(path))
        frames = frames[None, ...]
        # Initialize placeholders to store the masks and features of the current video.
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels


train_data, train_labels = prepare_all_videos(train_df)
test_data, test_labels = prepare_all_videos(test_df)

print("train_video_data")
# print(train_data)
print("train_video_labels")
# print(train_labels)

print("test_video_data")
# print(test_data)
print("test_video_labels")
# print(test_labels)

# print(f"Frame features in train set: {train_data[0].shape}")
# print(f"Frame masks in train set: {train_data[1].shape}")
# print(f"train_labels in train set: {train_labels.shape}")
# print(f"test_labels in train set: {test_labels.shape}")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 186ms/step
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# print("train_video_data")
# print(train_data)
# print("train_video_labels")
# print(train_labels)

# print("test_video_data")
# print(test_data)
# print("test_video_labels")
# print(test_labels)

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
print(f"train_labels in train set: {train_labels.shape}")
print(f"test_labels in train set: {test_labels.shape}")
# Out:
# Frame features in train set: (152, 20, 2048)
# Frame masks in train set: (152, 20)
# train_labels in train set: (152, 1)
# test_labels in train set: (38, 1)

# %% [markdown]
# ### The sequence model
# Now, we can feed this data to a sequence model consisting of recurrent layers like GRU.

# %%
# Utility for our sequence model.
def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.GRU(16, return_sequences=True)(frame_features_input, mask=mask_input)
    x = keras.layers.GRU(8)(x)
    x = keras.layers.Dropout(0.4)(x)
    x = keras.layers.Dense(8, activation="relu")(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    rnn_model.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return rnn_model

EPOCHS = 30
# Utility for running experiments.
def run_experiment():
    filepath = "./tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.3,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


_, sequence_model = run_experiment()
# Out:
# Epoch 1/30
# 3/4 [=====================>........] - ETA: 0s - loss: 1.1154 - accuracy: 0.3750
# Epoch 1: val_loss improved from inf to 1.08130, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 22s 2s/step - loss: 1.1091 - accuracy: 0.3679 - val_loss: 1.0813 - val_accuracy: 0.4348
# Epoch 2/30
# 4/4 [==============================] - ETA: 0s - loss: 1.0672 - accuracy: 0.4717
# Epoch 2: val_loss improved from 1.08130 to 1.07999, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 3s 839ms/step - loss: 1.0672 - accuracy: 0.4717 - val_loss: 1.0800 - val_accuracy: 0.4348
# Epoch 3/30
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0723 - accuracy: 0.3958
# Epoch 3: val_loss improved from 1.07999 to 1.07335, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 155ms/step - loss: 1.0770 - accuracy: 0.4151 - val_loss: 1.0734 - val_accuracy: 0.4348
# Epoch 4/30
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0835 - accuracy: 0.4375
# Epoch 4: val_loss improved from 1.07335 to 1.06364, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 169ms/step - loss: 1.1017 - accuracy: 0.4245 - val_loss: 1.0636 - val_accuracy: 0.4348
# Epoch 5/30
# 4/4 [==============================] - ETA: 0s - loss: 1.0175 - accuracy: 0.5377
# Epoch 5: val_loss improved from 1.06364 to 1.06073, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 164ms/step - loss: 1.0175 - accuracy: 0.5377 - val_loss: 1.0607 - val_accuracy: 0.4348
# Epoch 6/30
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0441 - accuracy: 0.4792
# Epoch 6: val_loss improved from 1.06073 to 1.05244, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 796ms/step - loss: 1.0419 - accuracy: 0.4811 - val_loss: 1.0524 - val_accuracy: 0.4348
# Epoch 7/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9889 - accuracy: 0.5000
# Epoch 7: val_loss improved from 1.05244 to 1.03951, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 161ms/step - loss: 0.9876 - accuracy: 0.5094 - val_loss: 1.0395 - val_accuracy: 0.4348
# Epoch 8/30
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0122 - accuracy: 0.5104
# Epoch 8: val_loss improved from 1.03951 to 1.02655, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 0s 149ms/step - loss: 0.9953 - accuracy: 0.5377 - val_loss: 1.0265 - val_accuracy: 0.4348
# Epoch 9/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9964 - accuracy: 0.5104
# Epoch 9: val_loss improved from 1.02655 to 1.01889, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 175ms/step - loss: 1.0001 - accuracy: 0.5094 - val_loss: 1.0189 - val_accuracy: 0.4348
# Epoch 10/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9742 - accuracy: 0.5729
# Epoch 10: val_loss improved from 1.01889 to 1.00974, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 153ms/step - loss: 0.9789 - accuracy: 0.5755 - val_loss: 1.0097 - val_accuracy: 0.5000
# Epoch 11/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9948 - accuracy: 0.5312
# Epoch 11: val_loss improved from 1.00974 to 1.00336, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 154ms/step - loss: 0.9867 - accuracy: 0.5283 - val_loss: 1.0034 - val_accuracy: 0.5217
# Epoch 12/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9447 - accuracy: 0.5833
# Epoch 12: val_loss improved from 1.00336 to 0.99352, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 0s 150ms/step - loss: 0.9438 - accuracy: 0.5849 - val_loss: 0.9935 - val_accuracy: 0.5000
# Epoch 13/30
# 4/4 [==============================] - ETA: 0s - loss: 0.9368 - accuracy: 0.5755
# Epoch 13: val_loss improved from 0.99352 to 0.99171, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 247ms/step - loss: 0.9368 - accuracy: 0.5755 - val_loss: 0.9917 - val_accuracy: 0.4348
# Epoch 14/30
# 4/4 [==============================] - ETA: 0s - loss: 0.9301 - accuracy: 0.5755
# Epoch 14: val_loss improved from 0.99171 to 0.98422, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 745ms/step - loss: 0.9301 - accuracy: 0.5755 - val_loss: 0.9842 - val_accuracy: 0.5000
# Epoch 15/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8856 - accuracy: 0.5938
# Epoch 15: val_loss improved from 0.98422 to 0.98172, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 163ms/step - loss: 0.8882 - accuracy: 0.6038 - val_loss: 0.9817 - val_accuracy: 0.5217
# Epoch 16/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8819 - accuracy: 0.6354
# Epoch 16: val_loss improved from 0.98172 to 0.96349, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 156ms/step - loss: 0.8798 - accuracy: 0.6415 - val_loss: 0.9635 - val_accuracy: 0.5217
# Epoch 17/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8947 - accuracy: 0.5729
# Epoch 17: val_loss did not improve from 0.96349
# 4/4 [==============================] - 0s 70ms/step - loss: 0.8881 - accuracy: 0.5849 - val_loss: 0.9642 - val_accuracy: 0.4783
# Epoch 18/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8251 - accuracy: 0.7083
# Epoch 18: val_loss improved from 0.96349 to 0.96072, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 3s 841ms/step - loss: 0.8429 - accuracy: 0.6887 - val_loss: 0.9607 - val_accuracy: 0.5652
# Epoch 19/30
# 4/4 [==============================] - ETA: 0s - loss: 0.8437 - accuracy: 0.7170
# Epoch 19: val_loss improved from 0.96072 to 0.95139, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 168ms/step - loss: 0.8437 - accuracy: 0.7170 - val_loss: 0.9514 - val_accuracy: 0.5870
# Epoch 20/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7643 - accuracy: 0.7708
# Epoch 20: val_loss did not improve from 0.95139
# 4/4 [==============================] - 0s 76ms/step - loss: 0.7724 - accuracy: 0.7358 - val_loss: 0.9526 - val_accuracy: 0.5000
# Epoch 21/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7873 - accuracy: 0.6875
# Epoch 21: val_loss improved from 0.95139 to 0.93269, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 772ms/step - loss: 0.7857 - accuracy: 0.6887 - val_loss: 0.9327 - val_accuracy: 0.6522
# Epoch 22/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7419 - accuracy: 0.7812
# Epoch 22: val_loss improved from 0.93269 to 0.93151, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 162ms/step - loss: 0.7523 - accuracy: 0.7547 - val_loss: 0.9315 - val_accuracy: 0.6304
# Epoch 23/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7465 - accuracy: 0.7396
# Epoch 23: val_loss improved from 0.93151 to 0.92094, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 791ms/step - loss: 0.7413 - accuracy: 0.7453 - val_loss: 0.9209 - val_accuracy: 0.6304
# Epoch 24/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7130 - accuracy: 0.7917
# Epoch 24: val_loss improved from 0.92094 to 0.90994, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6975 - accuracy: 0.7925 - val_loss: 0.9099 - val_accuracy: 0.5435
# Epoch 25/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7071 - accuracy: 0.7292
# Epoch 25: val_loss did not improve from 0.90994
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6917 - accuracy: 0.7547 - val_loss: 0.9558 - val_accuracy: 0.5652
# Epoch 26/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6511 - accuracy: 0.8229
# Epoch 26: val_loss improved from 0.90994 to 0.89519, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 749ms/step - loss: 0.6628 - accuracy: 0.8113 - val_loss: 0.8952 - val_accuracy: 0.6087
# Epoch 27/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5913 - accuracy: 0.8229
# Epoch 27: val_loss improved from 0.89519 to 0.89098, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 177ms/step - loss: 0.5987 - accuracy: 0.8208 - val_loss: 0.8910 - val_accuracy: 0.5652
# Epoch 28/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5531 - accuracy: 0.7812
# Epoch 28: val_loss improved from 0.89098 to 0.87889, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 2s 814ms/step - loss: 0.5552 - accuracy: 0.7642 - val_loss: 0.8789 - val_accuracy: 0.6087
# Epoch 29/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5675 - accuracy: 0.8229
# Epoch 29: val_loss improved from 0.87889 to 0.86297, saving model to ./tmp\video_classifier
# 4/4 [==============================] - 1s 163ms/step - loss: 0.5710 - accuracy: 0.8113 - val_loss: 0.8630 - val_accuracy: 0.6522
# Epoch 30/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5515 - accuracy: 0.8750
# Epoch 30: val_loss did not improve from 0.86297
# 4/4 [==============================] - 0s 70ms/step - loss: 0.5697 - accuracy: 0.8491 - val_loss: 0.9430 - val_accuracy: 0.5870
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0344 - accuracy: 0.5000
# Test accuracy: 50.0%

# %% [markdown]
# ### Inference

# %%
def prepare_single_video(frames):
    frames = frames[None, ...]
    frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
        frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

    return frame_features, frame_mask


def sequence_prediction(path):
    class_vocab = label_processor.get_vocabulary()

    frames = load_video(os.path.join(path))
    frame_features, frame_mask = prepare_single_video(frames)
    probabilities = sequence_model.predict([frame_features, frame_mask])[0]

    for i in np.argsort(probabilities)[::-1]:
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    return frames

test_video = np.random.choice(test_df["video_name"].values.tolist())
# print(f"Test video path: {test_video}")
print(test_video)
test_frames = sequence_prediction(test_video)
# Out:
# data/arrest/Arrest051_x264.mp4
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 114ms/step
#   roadaccidents: 59.73%
#   arrest: 25.97%
#   arson: 14.30%
